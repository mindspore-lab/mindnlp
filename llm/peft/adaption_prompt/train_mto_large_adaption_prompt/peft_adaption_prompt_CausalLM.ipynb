# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
model_name_or_path ="trl-internal-testing/tiny-random-LlamaForCausalLM"
tokenizer_name_or_path ="trl-internal-testing/tiny-random-LlamaForCausalLM"
text_column = "sentence"
label_column = "text_label"
max_length = 128
lr = 8e-3
num_epochs = 3
batch_size = 8

# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
from mindnlp.peft import get_peft_config, get_peft_model,AdaptionPromptConfig, get_peft_model_state_dict, IA3Config, TaskType
import mindspore
import datasets
from mindnlp.transformers import AutoTokenizer, AutoModelForCausalLM,LlamaForCausalLM

model= AutoModelForCausalLM.from_pretrained(model_name_or_path)
peft_config =AdaptionPromptConfig(adapter_layers=2, adapter_len=4, task_type="CAUSAL_LM")
model = get_peft_model(model,peft_config) 
model.print_trainable_parameters()
# Out:
#   0%|          | 0.00/331 [00:00<?, ?B/s]
#   0%|          | 0.00/3.94M [00:00<?, ?B/s]
#   0%|          | 0.00/138 [00:00<?, ?B/s]
# The following parameters in checkpoint files are not loaded:
# ['model.layers.0.self_attn.rotary_emb.inv_freq', 'model.layers.1.self_attn.rotary_emb.inv_freq']
# Matching module found: model.layers.0.self_attn
# Matching module found: model.layers.1.self_attn
# Collected parents for adapter layers: 2
# trainable params: 130 || all params: 1,032,402 || trainable%: 0.012591994203808207
